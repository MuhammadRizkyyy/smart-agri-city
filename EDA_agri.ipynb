# %% [markdown]
# # 🌾 Smart Agri City - EDA Notebook
# Generated for **KEL-13 Python ML Service** validation.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
print('📦 Analysis libraries loaded successfully!')

# %%
# Load and inspect dataset structures
df_yield = pd.read_csv('data/crop_yield.csv')
df_pest = pd.read_csv('data/pest_disease.csv')
df_irrig = pd.read_csv('data/irrigation_demand.csv')
print('✅ All CSV data shapes verified:', df_yield.shape, df_pest.shape, df_irrig.shape)

# %%
# Check target distributions
print(df_pest['pest_category'].value_counts(normalize=True))
